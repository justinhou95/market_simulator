# %%
import datetime
import numpy as np
import pandas_datareader as pdr
import esig
from tqdm.auto import tqdm
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
import base
from utils import tosig
from utils.leadlag import leadlag
from rough_bergomi import rough_bergomi

from importlib import reload
import cvae_keras
reload(cvae_keras)
import cvae_tfp
reload(cvae_tfp)

import matplotlib.pyplot as plt

# %% [markdown]
# ## Data processing

# %%
# # S&P 500
# data = pdr.get_data_yahoo("^GSPC", datetime.date(2000, 1, 1), datetime.date(2019, 1, 1))["Close"]
# windows = []
# for _, window in data.resample('M'):
#     values = window.values
#     path = leadlag(values)
#     windows.append(path)

# %%
# Actually for rough_bergomi model, conditional VAE does no help because the cond are independent

# rough_bergomi
params = {
            "M": 1000,
            "H": 0.14,
            "rho": -0.85,
            "xi0": 0.1,
            "nu": 1.5,
            "S0": 1.
          }

def _load_rough_bergomi(params, freq, test_use = False):
    grid_points_dict = {"M": 28, "W": 10, "Y": 252}
    grid_points = grid_points_dict[freq]
    params["T"] = grid_points / grid_points_dict["Y"]
    paths = rough_bergomi(grid_points, **params)
    if test_use:
        windows = paths
    else:   
        windows = [leadlag(path) for path in paths]
    return windows

windows = _load_rough_bergomi(params, 'W')

for path in windows:
    returns = path[::2, 1] / path[0, 1]
    plt.plot(returns, "b", alpha=0.1)

plt.title("Monthly paths")
plt.xlabel("Days")
plt.show()

# %%
windows_aug = _load_rough_bergomi(params, 'W', True)
helper = np.tile(np.arange(10)/10, [1000,1])
windows = np.concatenate([helper[:,:,None], windows_aug[:,:,None]],axis = -1)

# %%
import signatory
import torch

# %%
signatory.logsignature(torch.tensor(windows, dtype = torch.float), 10)
# Out:
# tensor([[ 9.0000e-01,  4.8084e-03, -3.0387e-04,  ...,  5.3627e-18,
#          -1.4356e-17,  4.3257e-22],
#         [ 9.0000e-01, -4.0898e-02, -3.9225e-02,  ...,  9.2163e-14,
#          -2.2332e-13, -1.0163e-16],
#         [ 9.0000e-01,  1.9209e-02, -1.2318e-02,  ..., -7.4530e-20,
#           7.3396e-20,  1.8180e-23],
#         ...,
#         [ 9.0000e-01, -2.3730e-03,  9.7769e-03,  ...,  3.3912e-19,
#          -5.8223e-19,  3.7830e-22],
#         [ 9.0000e-01, -7.4877e-03,  2.6391e-02,  ..., -3.4558e-15,
#           6.9324e-15,  1.3959e-17],
#         [ 9.0000e-01, -2.5910e-02, -9.7219e-03,  ..., -9.0189e-20,
#           8.7626e-19, -2.3060e-22]])

# %% [markdown]
# ## Log-signature computing

# %%
order = 4
def _logsig(path):
    return esig.tosig.stream2logsig(path, order)
def _sig(path):
    return esig.tosig.stream2sig(path, order)

train_windows = _load_rough_bergomi(params, 'M')
train_logsig = np.array([_logsig(path) for path in tqdm(train_windows, desc="Computing log-signatures")])
train_sig = np.array([_sig(path) for path in tqdm(train_windows, desc="Computing signatures")])

test_windows = _load_rough_bergomi(params, 'M')
test_logsig = np.array([_logsig(path) for path in tqdm(test_windows, desc="Computing log-signatures")])
test_sig = np.array([_sig(path) for path in tqdm(test_windows, desc="Computing signatures")])

scaler_logsig = MinMaxScaler(feature_range=(0.00001, 0.99999))
logsig_transformed = scaler_logsig.fit_transform(train_logsig)

scaler_sig = MinMaxScaler(feature_range=(0.00001, 0.99999))
sig_transformed = scaler_sig.fit_transform(train_sig)

data = logsig_transformed[1:]   # 1 week forecasting 1 week 
data_cond = logsig_transformed[:-1] 
scaler = scaler_logsig

# data = sig_transformed[1:]   # 1 week forecasting 1 week 
# data_cond = sig_transformed[:-1] 
# scaler = scaler_sig
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-100-4e374e0c8f88> in <module>
#       5     return esig.tosig.stream2sig(path, order)
#       6
# ----> 7 train_windows = _load_rough_bergomi(params)
#       8 train_logsig = np.array([_logsig(path) for path in tqdm(train_windows, desc="Computing log-signatures")])
#       9 train_sig = np.array([_sig(path) for path in tqdm(train_windows, desc="Computing signatures")])
#
# TypeError: _load_rough_bergomi() missing 1 required positional argument: 'freq'

# %% [markdown]
# ## CVAE

# %%
# Standard normal (tfp)
reload(cvae_tfp)
sample_dim = data.shape[0]
data_dim = data.shape[-1]
cond_dim = data_cond.shape[-1]
latent_dim = 8
hidden_dim = 50
weight = 0.001

x_input = [data, data_cond]
encoder = cvae_tfp.Encoder(data_dim, cond_dim, latent_dim, hidden_dim)
sampler = cvae_tfp.NormalSampler(latent_dim)
encodersampler = cvae_tfp.EncoderSampler(encoder,sampler)
decoder = cvae_tfp.Decoder(data_dim, cond_dim, latent_dim, hidden_dim)
model_normal = cvae_tfp.CVAE_bergomi(data_dim, cond_dim, latent_dim, hidden_dim, weight, decoder, encodersampler)
model_normal.compile(optimizer='adam', loss=cvae_tfp.zero_error)
model_normal.fit(x = x_input, y = data, epochs=10000,batch_size=sample_dim, verbose = True)

normalised_generated1 = model_normal.generate(data_cond)
# Out:
# Epoch 1/10000
# 1/1 [==============================] - 1s 1s/step - loss: 0.8459
# Epoch 2/10000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.8008
# Epoch 3/10000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7575
# Epoch 4/10000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.7236
# Epoch 5/10000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6660
# Epoch 6/10000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6342
# Epoch 7/10000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5908
# Epoch 8/10000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.5570
# Epoch 9/10000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5191
# Epoch 10/10000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4758
# Epoch 11/10000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.4460
# Epoch 12/10000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4160
# Epoch 13/10000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3820
# Epoch 14/10000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.3549
# Epoch 15/10000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.3279
# Epoch 16/10000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2960
# Epoch 17/10000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2735
# Epoch 18/10000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2387
# Epoch 19/10000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2203
# Epoch 20/10000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1987
# Epoch 21/10000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1766
# Epoch 22/10000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1588
# Epoch 23/10000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1491
# Epoch 24/10000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1352
# Epoch 25/10000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1212
# Epoch 26/10000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1097
# Epoch 27/10000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1000
# Epoch 28/10000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0953
# Epoch 29/10000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0878
# Epoch 30/10000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0849
# Epoch 31/10000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0807
# Epoch 32/10000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0764
# Epoch 33/10000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0747
# Epoch 34/10000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0734
# Epoch 35/10000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0701
# Epoch 36/10000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0666
# Epoch 37/10000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0671
# Epoch 38/10000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0637
# Epoch 39/10000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0607
# Epoch 40/10000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0578
# Epoch 41/10000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0558
# Epoch 42/10000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0554
# Epoch 43/10000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0543
# Epoch 44/10000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0530
# Epoch 45/10000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0521
# Epoch 46/10000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0515
# Epoch 47/10000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0525
# Epoch 48/10000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0505
# Epoch 49/10000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0505
# Epoch 50/10000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0507
# Epoch 51/10000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0504
# Epoch 52/10000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0505
# Epoch 53/10000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0490
# Epoch 54/10000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0474
# Epoch 55/10000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0483
# Epoch 56/10000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0486
# Epoch 57/10000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0489
# Epoch 58/10000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0480
# Epoch 59/10000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0474
# Epoch 60/10000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0474
# Epoch 61/10000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0476
# Epoch 62/10000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0477
# Epoch 63/10000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.

# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=999.0), HTML(value='')))

# %%
# # Student-t (tfp)
# reload(cvae_tfp)
# sample_dim = data.shape[0]
# data_dim = data.shape[-1]
# cond_dim = data_cond.shape[-1]
# latent_dim = 8
# hidden_dim = 50
# weight = 0.003

# x_input = [data, data_cond]
# encoder = cvae_tfp.Encoder_Pseudo(data_dim, cond_dim, latent_dim, hidden_dim)
# sampler = cvae_tfp.StudentSampler(latent_dim)
# encodersampler = cvae_tfp.EncoderSampler(encoder,sampler)
# decoder = cvae_tfp.Decoder(data_dim, cond_dim, latent_dim, hidden_dim)
# model_student = cvae_tfp.CVAE_bergomi(data_dim, cond_dim, latent_dim, hidden_dim, weight, decoder, encodersampler)
# model_student.compile(optimizer='adam', loss=cvae_tfp.zero_error)
# model_student.fit(x = x_input, y = data, epochs=10000,batch_size=sample_dim, verbose = True)

# normalised_generated2 = model_student.generate(data_cond)
# generated_logsig2 = scaler.inverse_transform(normalised_generated2)
# generated_sig2 = np.array([tosig.logsig2sig(logsig, 2, order) for logsig in tqdm(generated_logsig2)])

# %%
# df,_,_ = model_student.encodersampler.encoder(x_input)
# df

# %%
## VAE
# generator2 = cvae_keras.VAE(n_latent=8, n_hidden = 50, alpha=0.003)
# generator2.build(logsig.shape[-1])
# generator2.train(logsig, n_epochs=10000)
# normalised_generated2 = np.array([generator2.generate()[0] for i in range(len(logsig))])
# generated2 = scaler.inverse_transform(normalised_generated2)
# generated_sigs2 = np.array([tosig.logsig2sig(logsig, 2, order) for logsig in tqdm(generated2)])
# real_sigs = np.array([tosig.logsig2sig(logsig, 2, order) for logsig in tqdm(orig_logsig)])

# %%
# CVAE_keras
# generator = cvae_keras.CVAE(n_latent=8, n_hidden = 50, alpha=0.003)
# generator.build(data.shape[-1], data_cond.shape[-1])
# generator.train(data, data_cond, n_epochs=10000)

# normalised_generated = np.array([generator.generate(cond)[0] for cond in data_cond])
# generated_logsig = scaler.inverse_transform(normalised_generated)
# generated_sig = np.array([tosig.logsig2sig(logsig, 2, order) for logsig in tqdm(generated_logsig)])
# real_sigs = np.array([tosig.logsig2sig(logsig, 2, order) for logsig in tqdm(orig_logsig)])

# %% [markdown]
# ## Comparison

# %%
from esig.tosig import sigkeys

keys = sigkeys(2, order).split()

factor = []
for i in keys:
    factor.append((np.ceil((len(i)-2)/2)))
factor = np.array(factor)

PROJECTIONS = [(4, 5), (2, 4), (6, 7), (9, 2)]

# set_sig = [train_sig, test_sig, generated_sig, generated_sig1, generated_sig2]
# set_name = ["Train data", "Test data", "CVAE normal (keras)", "CVAE normal (tfp)", "CVAE student (tfp)"]

set_sig = [train_sig, test_sig, generated_sig1]#, generated_sig2]
set_name = ["Train data", "Test data", "CVAE normal (tfp)"]#, "CVAE student (tfp)"]

plt.figure(figsize=(12, 8))
for i, projection in enumerate(PROJECTIONS):
    plt.subplot(2, 2, i + 1)
    for j, signame in enumerate(zip(set_sig, set_name)):
        sig, name = signame
        plt.scatter(sig[:, projection[0]], sig[:, projection[1]],label=name, alpha = 0.9)
    plt.xlabel(keys[projection[0]], fontsize=14)
    plt.ylabel(keys[projection[1]], fontsize=14)
#     plt.xticks([])
#     plt.yticks([])
    plt.legend()
    
plt.show()

# %%
from esig.tosig import logsigkeys
import re

logkeys = logsigkeys(2, order).split()

logfactor = []
for i in logkeys:
    logfactor.append((len(re.sub("\D", "", i))))
logfactor = np.array(logfactor)

PROJECTIONS = [(4, 5), (2, 4), (6, 7), (1, 7)]

set_logsig = [train_logsig, test_logsig, generated_logsig1]#, generated_logsig2]
set_name = ["Train data", "Test data", "CVAE normal (tfp)"]#, "CVAE student (tfp)"]

plt.figure(figsize=(12, 8))
for i, projection in enumerate(PROJECTIONS):
    plt.subplot(2, 2, i+1)
    for sig, name in zip(set_logsig, set_name):
        plt.scatter(sig[:, projection[0]], sig[:, projection[1]],label=name, alpha = 0.9)
        
    plt.xlabel(logkeys[projection[0]], fontsize=14)
    plt.ylabel(logkeys[projection[1]], fontsize=14)
#     plt.xticks([])
#     plt.yticks([])
    plt.legend()
plt.show()

# %% [markdown]
# ## Evaluation

# %%
import evaluation
reload(evaluation)

import process_discriminator
reload(process_discriminator)
# Out:
# <module 'process_discriminator' from '../src\\process_discriminator.py'>

# %%
phi1 = process_discriminator.T_global(test_sig[1:], generated_sig1,\
                                     order=4, verbose=False, normalise=True, compute_sigs=False)
phi2 = process_discriminator.T_global(test_sig[1:], generated_sig2,\
                                     order=4, verbose=False, normalise=True, compute_sigs=False)
phi = min(phi1,phi2)
# Out:
# ====================================================================================================
# 0.9999999999951377
# ====================================================================================================
# ====================================================================================================
# 0.9999999999964828
# ====================================================================================================

# %%
TU0 = []
TU1 = []
TU2 = []
for i in range(10):
    windows1 = _load_rough_bergomi(params)
    sig1 = np.array([_sig(path) for path in tqdm(windows1, desc="Computing signatures")])
    
    windows2 = _load_rough_bergomi(params)
    sig2 = np.array([_sig(path) for path in tqdm(windows2, desc="Computing signatures")])

    normalised_generated1 = model_normal.generate(data_cond)
    generated_logsig1 = scaler.inverse_transform(normalised_generated1)
    generated_sig1 = np.array([tosig.logsig2sig(logsig, 2, order) for logsig in tqdm(generated_logsig1)])

    normalised_generated2 = model_student.generate(data_cond)
    generated_logsig2 = scaler.inverse_transform(normalised_generated2)
    generated_sig2 = np.array([tosig.logsig2sig(logsig, 2, order) for logsig in tqdm(generated_logsig2)])
    
    result, TU = process_discriminator.test_fix(sig1[1:], sig2[1:],\
                                                order=order, confidence_level=0.99, phi_x = phi, compute_sigs=False)
    TU0.append(TU)
    result, TU = process_discriminator.test_fix(sig1[1:], generated_sig1,\
                                                order=order, confidence_level=0.99, phi_x = phi, compute_sigs=False)
    TU1.append(TU)
    result, TU = process_discriminator.test_fix(sig1[1:], generated_sig2,\
                                                order=order, confidence_level=0.99, phi_x = phi, compute_sigs=False)
    TU2.append(TU)
# Out:
# HBox(children=(HTML(value='Computing signatures'), FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# HBox(children=(HTML(value='Computing signatures'), FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=999.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=999.0), HTML(value='')))
# HBox(children=(HTML(value='Computing signatures of population 1'), FloatProgress(value=0.0, max=999.0), HTML(v…
# HBox(children=(HTML(value='Computing signatures of population 2'), FloatProgress(value=0.0, max=999.0), HTML(v…
# 0.9999999999951377
# c: 0.012687251081145167
# TU: 4.311966741932238e-05
# m: 999
# HBox(children=(HTML(value='Computing signatures of population 1'), FloatProgress(value=0.0, max=999.0), HTML(v…
# HBox(children=(HTML(value='Computing signatures of population 2'), FloatProgress(value=0.0, max=999.0), HTML(v…
# 0.9999999999951377
# c: 0.012687251081145167
# TU: 0.00036006606468319546
# m: 999
# HBox(children=(HTML(value='Computing signatures of population 1'), FloatProgress(value=0.0, max=999.0), HTML(v…
# HBox(children=(HTML(value='Computing signatures of population 2'), FloatProgress(value=0.0, max=999.0), HTML(v…
# 0.9999999999951377
# c: 0.012687251081145167
# TU: 0.003187642465826368
# m: 999
# HBox(children=(HTML(value='Computing signatures'), FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# HBox(children=(HTML(value='Computing signatures'), FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=999.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=999.0), HTML(value='')))
# HBox(children=(HTML(value='Computing signatures of population 1'), FloatProgress(value=0.0, max=999.0), HTML(v…
# HBox(children=(HTML(value='Computing signatures of population 2'), FloatProgress(value=0.0, max=999.0), HTML(v…
# 0.9999999999951377
# c: 0.012687251081145167
# TU: 7.580322285871688e-06
# m: 999
# HBox(children=(HTML(value='Computing signatures of population 1'), FloatProgress(value=0.0, max=999.0), HTML(v…
# HBox(children=(HTML(value='Computing signatures of population 2'), FloatProgress(value=0.0, max=999.0), HTML(v…
# 0.9999999999951377
# c: 0.012687251081145167
# TU: 0.00038785782698891325
# m: 999
# HBox(children=(HTML(value='Computing signatures of population 1'), FloatProgress(value=0.0, max=999.0), HTML(v…
# HBox(children=(HTML(value='Computing signatures of population 2'), FloatProgress(value=0.0, max=999.0), HTML(v…
# 0.9999999999951377
# c: 0.012687251081145167
# TU: 0.0034877650514371084
# m: 999
# HBox(children=(HTML(value='Computing signatures'), FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# HBox(children=(HTML(value='Computing signatures'), FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=999.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=999.0), HTML(value='')))
# HBox(children=(HTML(value='Computing signatures of population 1'), FloatProgress(value=0.0, max=999.0), HTML(v…
# HBox(children=(HTML(value='Computing signatures of population 2'), FloatProgress(value=0.0, max=999.0), HTML(v…
# 0.9999999999951377
# c: 0.012687251081145167
# TU: 1.4834959827680905e-05
# m: 999
# HBox(children=(HTML(value='Computing signatures of population 1'), FloatProgress(value=0.0, max=999.0), HTML(v…
# HBox(children=(HTML(value='Computing signatures of population 2'), FloatProgress(value=0.0, max=999.0), HTML(v…
# 0.9999999999951377
# c: 0.012687251081145167
# TU: 0.0004598876646619843
# m: 999
# HBox(children=(HTML(value='Computing signatures of population 1'), FloatProgress(value=0.0, max=999.0), HTML(v…
# HBox(children=(HTML(value='Computing signatures of population 2'), FloatProgress(value=0.0, max=999.0), HTML(v…
# 0.9999999999951377
# c: 0.012687251081145167
# TU: 0.004480831278007358
# m: 999
# HBox(children=(HTML(value='Computing signatures'), FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# HBox(children=(HTML(value='Computing signatures'), FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=999.0), HTML(value='')))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-280563e48936> in <module>
#      11     normalised_generated1 = model_normal.generate(data_cond)
#      12     generated_logsig1 = scaler.inverse_transform(normalised_generated1)
# ---> 13     generated_sig1 = np.array([tosig.logsig2sig(logsig, 2, order) for logsig in tqdm(generated_logsig1)])
#      14
#      15     normalised_generated2 = model_student.generate(data_cond)
#
# <ipython-input-14-280563e48936> in <listcomp>(.0)
#      11     normalised_generated1 = model_normal.generate(data_cond)
#      12     generated_logsig1 = scaler.inverse_transform(normalised_generated1)
# ---> 13     generated_sig1 = np.array([tosig.logsig2sig(logsig, 2, order) for logsig in tqdm(generated_logsig1)])
#      14
#      15     normalised_generated2 = model_student.generate(data_cond)
#
# C:\SongyanHou\Study\Codes\MASTER\market_simulator\src\utils\tosig.py in logsig2sig(logsig, width, depth)
#     316     L = {i + 1: l for i, l in enumerate(logsig)}
#     317
# --> 318     tensor = lie2tensor(L, width, depth)[1:]
#     319
#     320     return tensor_exp(np.r_[width, tensor], depth)[1:]
#
# C:\SongyanHou\Study\Codes\MASTER\market_simulator\src\utils\tosig.py in lie2tensor(lie_element, width, depth)
#     285
#     286     """
# --> 287     return li.l2t(lie_element, width, depth)
#     288
#     289 #@decorators.accepts((list, np.ndarray))
#
# C:\SongyanHou\Study\Codes\MASTER\market_simulator\src\utils\tjl_hall_numpy_lie.py in l2t(arg, width, depth)
#     348         if k:
#     349             ans = tjl_dense_numpy_tensor.tensor_add(
# --> 350                 ans, (tjl_dense_numpy_tensor.rescale(_expand(k), arg[k]))
#     351             )
#     352     return ans
#
# C:\SongyanHou\Study\Codes\MASTER\market_simulator\src\utils\tjl_hall_numpy_lie.py in <lambda>(k)
#     342 >>>
#     343     """
# --> 344     _expand = lambda k: expand(k, width, depth)
#     345     _tensor_add = tjl_dense_numpy_tensor.tensor_add
#     346     ans = tjl_dense_numpy_tensor.zero(width)
#
# C:\SongyanHou\Study\Codes\MASTER\market_simulator\src\utils\tjl_hall_numpy_lie.py in expand(k, width, depth)
#     320             return _tensor_sub(
#     321                 _tensor_multiply(_expand(k1), _expand(k2)),
# --> 322                 _tensor_multiply(_expand(k2), _expand(k1)),
#     323             )
#     324         else:
#
# C:\SongyanHou\Study\Codes\MASTER\market_simulator\src\utils\tjl_hall_numpy_lie.py in <lambda>(k)
#     307 ## expand is a map from hall basis keys to tensors
#     308 def expand(k, width, depth):
# --> 309     _expand = lambda k: expand(k, width, depth)
#     310     _tensor_multiply = lambda k1, k2: tjl_dense_numpy_tensor.tensor_multiply(
#     311         k1, k2, depth
#
# C:\SongyanHou\Study\Codes\MASTER\market_simulator\src\utils\tjl_hall_numpy_lie.py in expand(k, width, depth)
#     319         if k1:
#     320             return _tensor_sub(
# --> 321                 _tensor_multiply(_expand(k1), _expand(k2)),
#     322                 _tensor_multiply(_expand(k2), _expand(k1)),
#     323             )
#
# C:\SongyanHou\Study\Codes\MASTER\market_simulator\src\utils\tjl_hall_numpy_lie.py in <lambda>(k1, k2)
#     308 def expand(k, width, depth):
#     309     _expand = lambda k: expand(k, width, depth)
# --> 310     _tensor_multiply = lambda k1, k2: tjl_dense_numpy_tensor.tensor_multiply(
#     311         k1, k2, depth
#     312     )
#
# C:\SongyanHou\Study\Codes\MASTER\market_simulator\src\utils\tjl_dense_numpy_tensor.py in tensor_multiply(lhs, rhs, depth)
#     193             rhsb = blob_size(width, j - 1)
#     194             rhse = blob_size(width, j)
# --> 195             ans[ansb:anse] += np.tensordot(
#     196                 np.reshape(lhs[lhsb:lhse], tensor_shape(i - j, width)),
#     197                 np.reshape(rhs[rhsb:rhse], tensor_shape(j, width)),
#
# KeyboardInterrupt:

# %%
TU = np.array([TU0, TU1, TU2])
label = ['TU0', 'TU1', 'TU2'] 
plt.figure(figsize = (10,4))
plt.hist(TU.T, bins = 20, density=True, histtype='bar', stacked=True, label = label)
plt.legend()
plt.show()

# %% [markdown]
# ## From Signature to Path

# %%
import logsig_inversion
from esig.tosig import stream2logsig
from utils.leadlag import leadlag
from gpsig import kernels
import gpflow

# %%
pip = 0.001
n_pips = 5 * 10
n_points = 28
n_iterations = 100
n_organisms = 100
recovered_paths = []
for i, logsig in enumerate(generated):
    recovered_paths.append(logsig_inversion.train(logsig, order, n_iterations, n_organisms, n_points, pip, n_pips)[0] + 1.)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))

# %%
plt.plot(np.array(recovered_paths).T, "b", alpha=0.1)
plt.show()
