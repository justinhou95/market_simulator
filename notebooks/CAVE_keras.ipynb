# %% [markdown]
# ## Simple implementation of CVAE with keras

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import utils
from sklearn.datasets import make_circles
from sklearn.preprocessing import MinMaxScaler
from tqdm.auto import tqdm
import tensorflow as tf
from importlib import reload
from tensorflow import keras
from tensorflow.keras import layers
import base
from utils import tosig
import cvae_keras
reload(cvae_keras)
# Out:
# <module 'cvae_keras' from '../src\\cvae_keras.py'>

# %%
data, conditions = make_circles(n_samples=10000, noise=0.05, factor=0.5)
scaler = MinMaxScaler()
data = scaler.fit_transform(data)
# Plot dataset
plt.scatter(*data.T, c=conditions, s=2)
plt.show()
data = utils.as_float_array(data)
data_cond = utils.as_float_array(conditions)
data_cond = data_cond.reshape(-1, 1)

# %% [markdown]
# ## CVAE

# %%
model = cvae_keras.CVAE(n_latent = 4, n_hidden=50, alpha = 0.02)
model.build(data.shape[-1],data_cond.shape[-1])
model.train(data,data_cond,n_epochs=5000)
# Out:
# Epoch 1/5000
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1286
# Epoch 2/5000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1275
# Epoch 3/5000
# 1/1 [==============================] - 0s 997us/step - loss: 0.1268
# Epoch 4/5000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1258
# Epoch 5/5000
# 1/1 [==============================] - 0s 997us/step - loss: 0.1250
# Epoch 6/5000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1240
# Epoch 7/5000
# 1/1 [==============================] - 0s 998us/step - loss: 0.1233
# Epoch 8/5000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1228
# Epoch 9/5000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1222
# Epoch 10/5000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1216
# Epoch 11/5000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1217
# Epoch 12/5000
# ...

# %%
n_samples = 1000

randoms = np.random.normal(0, 1, size=(n_samples, 4))
condi0 = np.zeros(shape=(n_samples, 1))
outputs0 = model.decoder([tf.constant(randoms), tf.constant(condi0)]).numpy()

randoms = np.random.normal(0, 1, size=(n_samples, 4))
condi1 = np.zeros(shape=(n_samples, 1)) + 1
outputs1 = model.decoder([tf.constant(randoms), tf.constant(condi1)]).numpy()

plt.scatter(*outputs0.T, s=2)
plt.scatter(*outputs1.T, s=2)

plt.show()

# %% [markdown]
# ## VAE

# %%
model2 = cvae_keras.VAE(n_latent = 4, n_hidden=50, alpha = 0.02)
model2.build(data.shape[-1])
model2.train(data,n_epochs=5000)
# Out:
# Epoch 1/5000
# 1/1 [==============================] - 0s 0s/step - loss: 0.1275
# Epoch 2/5000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1258
# Epoch 3/5000
# 1/1 [==============================] - 0s 998us/step - loss: 0.1252
# Epoch 4/5000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1247
# Epoch 5/5000
# 1/1 [==============================] - 0s 997us/step - loss: 0.1244
# Epoch 6/5000
# 1/1 [==============================] - 0s 994us/step - loss: 0.1230
# Epoch 7/5000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1226
# Epoch 8/5000
# 1/1 [==============================] - 0s 997us/step - loss: 0.1225
# Epoch 9/5000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1214
# Epoch 10/5000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1211
# Epoch 11/5000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1203
# Epoch 12/5000
# ...

# %%
n_samples = 1000
randoms = np.random.normal(0, 1, size=(n_samples, 4))
outputs = model2.decoder(tf.constant(randoms)).numpy()
plt.scatter(*outputs.T, s=2, alpha = 1)
plt.scatter(*data.T, s=2, alpha = 0.5)
